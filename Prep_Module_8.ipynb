# %% [markdown]
# <a href="https://colab.research.google.com/github/Daffodilpearlzz/FMML/blob/main/Prep_Module_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
my_data = pd.Series(np.random.randn(200))

# %%
my_data.shape
# Out:
# (200,)

# %%
type(my_data)
# Out:
# pandas.core.series.Series

# %%
sns.boxplot(data=my_data)

# %%
my_data.describe()
# Out:
# count    200.000000
# mean      -0.054113
# std        1.055544
# min       -2.556603
# 25%       -0.764668
# 50%       -0.040540
# 75%        0.636952
# max        2.820650
# dtype: float64

# %%
my_dataset = sns.load_dataset('tips')
my_dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(my_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
my_dataset.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
my_dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
my_dataset.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# Use seaborn to get useful data analysis

# %%
sns.scatterplot(x='tip', y='total_bill',data=my_dataset)

# %%
sns.scatterplot(x='tip',y='total_bill', data=my_dataset, hue='sex')

# %%
sns.scatterplot(y='tip',x='total_bill', data=my_dataset, hue='sex')

# %%
sns.scatterplot(x='tip',y='total_bill', hue='smoker', data=my_dataset)

# %%
sns.scatterplot(y='tip',x='total_bill', data=my_dataset,hue='day')

# %%
sns.scatterplot(y='tip',x='total_bill', data=my_dataset, hue='time')

# %%
sns.scatterplot(x='total_bill',y='day', data=my_dataset, hue='sex')

# %%
sns.boxplot(x='time',y='total_bill',data=my_dataset,hue='sex')

# %%
sns.boxplot(x='time',y='total_bill',hue='size',data=my_dataset)

# %%
sns.boxplot(x='time',y='size',data=my_dataset,hue='day')

# %%
sns.boxplot(x='size',y='total_bill',data=my_dataset,hue='sex')
